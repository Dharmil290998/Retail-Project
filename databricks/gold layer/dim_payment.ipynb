# %%
payment = spark.table("sales.silver.payment")

dim_payment = payment.select(
    "payment_id",
    "payment_method",
    "payment_status",
    "payment_time",
    "is_success"
)
dim_payment.write.mode("append").saveAsTable("sales.gold.dim_payment")
